# %%
# read csv file 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv file
df = pd.read_csv('NO_BROKER_combined_file.csv')
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1704967473-1  https://www.nobroker.in/property/sale/bangalor...
# 1      1704967475-2  https://www.nobroker.in/property/sale/bangalor...
# 2      1704967477-3  https://www.nobroker.in/property/sale/bangalor...
# 3      1704967480-4  https://www.nobroker.in/property/sale/bangalor...
# 4      1704967483-5  https://www.nobroker.in/property/sale/bangalor...
#
#                                               link01  \
# 0  2 BHK Flat In Vinayaka Terraces For Sale  In V...
# 1             3 BHK House For Sale  In Chandralayout
# 2            4 BHK House For Sale  In Chandra Layout
# 3            1 RK House For Sale  In  Chandra Layout
# 4               4 BHK House For Sale  In Vijayanagar
#
#                                          link01-href         price   sqft  \
# 0  https://www.nobroker.in/property/buy/2-bhk-apa...     ₹ 60 Lacs  1,030
# ...

# %%
# print all columns
print(df.columns)
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'link01', 'link01-href',
#        'price', 'sqft', 'bedroom', 'bathroom', 'balcony', 'apartment', 'age',
#        'ownership', 'maintenance', 'flooring', 'remove', 'furnishing',
#        'facing', 'floor', 'parking', 'gated_security', 'description',
#        'bus_station', 'amenities', 'address'],
#       dtype='object')

# %%
# drop columns that are not needed
df.drop(['web-scraper-order', 'web-scraper-start-url', 'link01',  'link01-href', 'remove', 'description', 'address'], axis=1, inplace=True)
df.head()
# Out:
#           price   sqft    bedroom    bathroom  balcony          apartment  \
# 0     ₹ 60 Lacs  1,030  2 Bedroom  2 Bathroom      1.0  Vinayaka Terraces
# 1     ₹ 60 Lacs  2,400  3 Bedroom  5 Bathroom      NaN  Independent House
# 2  ₹ 1.2 Crores  1,200  4 Bedroom  1 Bathroom      NaN  Independent House
# 3     ₹ 20 Lacs    450  1 Bedroom  1 Bathroom      NaN  Independent House
# 4  ₹ 5.5 Crores  2,200  4 Bedroom  3 Bathroom      NaN  Independent House
#
#          age   ownership maintenance         flooring  furnishing facing  \
# 0  >10 years  Self Owned   >10 years  Vitrified Tiles        Semi   East
# 1  3-5 years  Self Owned   3-5 years      2,400 sq.ft        East    4/4
# 2  >10 years  Self Owned   >10 years      1,200 sq.ft  Don't Know    0/0
# 3  >10 years  Self Owned   >10 years        450 sq.ft        East    0/1
# 4  >10 years  Self Owned   >10 years      2,200 sq.ft  South-East    0/0
#
#           floor parking gated_security  \
# ...

# %%
# print dimensions of the dataframe
print(df.shape)
# Out:
# (1809, 17)

# %%
# print the max and min in the price column 
print(df['price'].max())
print(df['price'].min())
# Out:
# ₹ 99.33 Lacs
# ₹ 1 Crore
